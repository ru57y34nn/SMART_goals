# %%
import csv
import pandas as pd
#import pg8000
import sys
import os
import pathlib2
import lims_sql_query as lsq
from speedml import Speedml
import pixiedust
pixiedust.optOut()
# Out:
# Pixiedust will not collect anonymous install statistics.

# %% [markdown]
# # Mouse

# %%
home = pathlib2.Path.home()
full_path = home/"documents"/"github"/"SMART_goals"/"data"/"mouse_smart_data.csv"
full_path = str(full_path)
full_path
mshiny = pd.read_csv(full_path)
mshiny = mshiny[["recording_date", "patched_cell_container", "anno.res_index_label", "name","63x_call"]]
mshiny = mshiny.set_index("recording_date")
mshiny
# Out:
#                         patched_cell_container  anno.res_index_label  \
# recording_date
# 2018-01-02 21:34:44.000    P8S4_180102_351_A01              1.000000
# 2018-01-02 21:56:41.000    P8S4_180102_352_A01              0.000000
# 2018-01-02 22:49:10.000    P8S4_180102_353_A01              0.745543
# 2018-01-02 21:08:13.000    P9S4_180102_401_A01              0.880454
# 2018-01-02 21:48:56.000    P9S4_180102_402_A01              1.000000
# 2018-01-02 22:30:24.000    P9S4_180102_403_A01              1.000000
# 2018-01-03 23:25:54.000    P8S4_180103_351_A01              0.000000
# 2018-01-03 23:51:16.000    P8S4_180103_352_A01              1.000000
# 2018-01-03 20:49:43.000    PAS4_180103_451_A01              0.880454
# 2018-01-03 22:42:05.000    PAS4_180103_452_A01              0.784887
# 2018-01-04 21:28:08.000    P8S4_180104_351_A01              0.703208
# 2018-01-08 18:23:10.000    P2S4_180108_051_A01              0.458638
# ...
